# %%
# init

import pandas as pd
import re

# %%
input_file = "rico_products_lm_updated.csv"
output_file = "rico_products_lm_barcodes_updated.csv"

df = pd.read_csv(input_file)

# %%
df.head()
# Out:
#                              Handle                             Title  \
# 0  rico-bb-clarinet-reeds-box-of-25  Rico Bb Clarinet Reeds Box of 25
# 1  rico-bb-clarinet-reeds-box-of-25                               NaN
# 2  rico-bb-clarinet-reeds-box-of-25                               NaN
# 3  rico-bb-clarinet-reeds-box-of-25                               NaN
# 4  rico-bb-clarinet-reeds-box-of-25                               NaN
#
#                                          Body (HTML) Vendor Product Category  \
# 0  <h1>Rico Bb Clarinet Reeds Box of 25</h1><p id...   Rico              NaN
# 1                                                NaN    NaN              NaN
# 2                                                NaN    NaN              NaN
# 3                                                NaN    NaN              NaN
# 4                                                NaN    NaN              NaN
#
#           Type            Tags Published   Option1 Name Option1 Value  ...  \
# ...

# %%
df['Variant Barcode'] = '0' + df['Variant Barcode'].astype(str)

# %%
df['Variant Barcode'] = df['Variant Barcode'].astype(str).apply(lambda x: re.sub( r'\.0$', '', x) )

# %%
df['Variant Barcode'] = df['Variant Barcode'].str.replace('0nan', '')

# %%
df['Variant Barcode']
# Out:
# 0      046716532350
# 1      046716532367
# 2      046716532374
# 3      046716532381
# 4      046716532398
#            ...
# 131    046716574213
# 132    046716575142
# 133    046716575159
# 134    046716575166
# 135    046716575173
# Name: Variant Barcode, Length: 136, dtype: object

# %%
df.to_csv(output_file, index=False)
